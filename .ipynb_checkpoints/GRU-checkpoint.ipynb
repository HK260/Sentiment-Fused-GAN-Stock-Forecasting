# %%
import time

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from numpy import *
from math import sqrt
from pandas import *
from datetime import datetime, timedelta
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Bidirectional
from tensorflow.keras.layers import BatchNormalization, Embedding, TimeDistributed, LeakyReLU
from tensorflow.keras.layers import GRU, LSTM
from tensorflow.keras.optimizers import Adam
from matplotlib import pyplot
from pickle import load

# %%
# Limit GPU memory to 50%
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    # Assuming your GPU has 8GB memory, you set memory_limit to 4GB (50%).
    tf.config.experimental.set_virtual_device_configuration(
        physical_devices[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)]  # 50% of 8GB GPU
    )

# %%
# Load data
X_train = np.load("X_train.npy", allow_pickle=True)
y_train = np.load("y_train.npy", allow_pickle=True)
X_test = np.load("X_test.npy", allow_pickle=True)
y_test = np.load("y_test.npy", allow_pickle=True)
yc_train = np.load("yc_train.npy", allow_pickle=True)
yc_test = np.load("yc_test.npy", allow_pickle=True)

# %%
input_dim = X_train.shape[1]
feature_size = X_train.shape[2]
output_dim = y_train.shape[1]

# %%
# Parameters
LR = 0.0001
BATCH_SIZE = 64
N_EPOCH = 50

# %%
def basic_GRU(input_dim, output_dim, feature_size, X_train, y_train, X_test, y_test, LR, N_EPOCH, BATCH_SIZE) -> tf.keras.models.Model:
    model = Sequential()
    model.add(GRU(units=128, return_sequences=True, input_shape=(input_dim, feature_size)))
    model.add(GRU(units=64))
    model.add(Dense(32))
    model.add(Dense(units=output_dim))
    model.compile(optimizer=Adam(lr=LR), loss='mse')

    history = model.fit(X_train, y_train, epochs=N_EPOCH, batch_size=BATCH_SIZE, validation_data=(X_test, y_test),
                        verbose=2, shuffle=False)

    return model, history

# %%
# Train the model
model, history = basic_GRU(input_dim, output_dim, feature_size, X_train, y_train, X_test, y_test, LR, N_EPOCH, BATCH_SIZE)
# Out:
# Epoch 1/50
# 6/6 - 5s - loss: 0.1659 - val_loss: 0.2612 - 5s/epoch - 861ms/step
# Epoch 2/50
# 6/6 - 0s - loss: 0.1004 - val_loss: 0.1419 - 147ms/epoch - 24ms/step
# Epoch 3/50
# 6/6 - 0s - loss: 0.0571 - val_loss: 0.0634 - 126ms/epoch - 21ms/step
# Epoch 4/50
# 6/6 - 0s - loss: 0.0324 - val_loss: 0.0222 - 145ms/epoch - 24ms/step
# Epoch 5/50
# 6/6 - 0s - loss: 0.0213 - val_loss: 0.0068 - 136ms/epoch - 23ms/step
# Epoch 6/50
# 6/6 - 0s - loss: 0.0171 - val_loss: 0.0038 - 140ms/epoch - 23ms/step
# Epoch 7/50
# 6/6 - 0s - loss: 0.0144 - val_loss: 0.0037 - 140ms/epoch - 23ms/step
# Epoch 8/50
# 6/6 - 0s - loss: 0.0114 - val_loss: 0.0034 - 115ms/epoch - 19ms/step
# Epoch 9/50
# 6/6 - 0s - loss: 0.0085 - val_loss: 0.0031 - 134ms/epoch - 22ms/step
# Epoch 10/50
# 6/6 - 0s - loss: 0.0066 - val_loss: 0.0033 - 119ms/epoch - 20ms/step
# Epoch 11/50
# 6/6 - 0s - loss: 0.0057 - val_loss: 0.0036 - 98ms/epoch - 16ms/step
# Epoch 12/50
# 6/6 - 0s - loss: 0.0054 - val_loss: 0.0036 - 123ms/epoch - 21ms/step
# Epoch 13/50
# 6/6 - 0s - loss: 0.0052 - val_loss: 0.0034 - 149ms/epoch - 25ms/step
# Epoch 14/50
# 6/6 - 0s - loss: 0.0051 - val_loss: 0.0031 - 86ms/epoch - 14ms/step
# Epoch 15/50
# 6/6 - 0s - loss: 0.0050 - val_loss: 0.0029 - 128ms/epoch - 21ms/step
# Epoch 16/50
# 6/6 - 0s - loss: 0.0049 - val_loss: 0.0028 - 127ms/epoch - 21ms/step
# Epoch 17/50
# 6/6 - 0s - loss: 0.0049 - val_loss: 0.0028 - 120ms/epoch - 20ms/step
# Epoch 18/50
# 6/6 - 0s - loss: 0.0049 - val_loss: 0.0028 - 128ms/epoch - 21ms/step
# Epoch 19/50
# 6/6 - 0s - loss: 0.0048 - val_loss: 0.0028 - 143ms/epoch - 24ms/step
# Epoch 20/50
# 6/6 - 0s - loss: 0.0048 - val_loss: 0.0028 - 135ms/epoch - 23ms/step
# Epoch 21/50
# 6/6 - 0s - loss: 0.0047 - val_loss: 0.0028 - 100ms/epoch - 17ms/step
# Epoch 22/50
# 6/6 - 0s - loss: 0.0047 - val_loss: 0.0028 - 121ms/epoch - 20ms/step
# Epoch 23/50
# 6/6 - 0s - loss: 0.0047 - val_loss: 0.0028 - 113ms/epoch - 19ms/step
# Epoch 24/50
# 6/6 - 0s - loss: 0.0047 - val_loss: 0.0028 - 123ms/epoch - 21ms/step
# Epoch 25/50
# 6/6 - 0s - loss: 0.0046 - val_loss: 0.0028 - 111ms/epoch - 19ms/step
# Epoch 26/50
# 6/6 - 0s - loss: 0.0046 - val_loss: 0.0027 - 92ms/epoch - 15ms/step
# Epoch 27/50
# 6/6 - 0s - loss: 0.0046 - val_loss: 0.0027 - 122ms/epoch - 20ms/step
# Epoch 28/50
# 6/6 - 0s - loss: 0.0045 - val_loss: 0.0027 - 128ms/epoch - 21ms/step
# Epoch 29/50
# 6/6 - 0s - loss: 0.0045 - val_loss: 0.0027 - 116ms/epoch - 19ms/step
# Epoch 30/50
# 6/6 - 0s - loss: 0.0045 - val_loss: 0.0027 - 114ms/epoch - 19ms/step
# Epoch 31/50
# 6/6 - 0s - loss: 0.0045 - val_loss: 0.0027 - 117ms/epoch - 19ms/step
# Epoch 32/50
# 6/6 - 0s - loss: 0.0044 - val_loss: 0.0027 - 126ms/epoch - 21ms/step
# Epoch 33/50
# 6/6 - 0s - loss: 0.0044 - val_loss: 0.0027 - 133ms/epoch - 22ms/step
# Epoch 34/50
# 6/6 - 0s - loss: 0.0044 - val_loss: 0.0026 - 123ms/epoch - 20ms/step
# Epoch 35/50
# 6/6 - 0s - loss: 0.0044 - val_loss: 0.0026 - 121ms/epoch - 20ms/step
# Epoch 36/50
# 6/6 - 0s - loss: 0.0043 - val_loss: 0.0026 - 135ms/epoch - 23ms/step
# Epoch 37/50
# 6/6 - 0s - loss: 0.0043 - val_loss: 0.0026 - 137ms/epoch - 23ms/step
# Epoch 38/50
# 6/6 - 0s - loss: 0.0043 - val_loss: 0.0026 - 116ms/epoch - 19ms/step
# Epoch 39/50
# 6/6 - 0s - loss: 0.0043 - val_loss: 0.0026 - 121ms/epoch - 20ms/step
# Epoch 40/50
# 6/6 - 0s - loss: 0.0042 - val_loss: 0.0026 - 133ms/epoch - 22ms/step
# Epoch 41/50
# 6/6 - 0s - loss: 0.0042 - val_loss: 0.0026 - 123ms/epoch - 20ms/step
# Epoch 42/50
# 6/6 - 0s - loss: 0.0042 - val_loss: 0.0025 - 98ms/epoch - 16ms/step
# Epoch 43/50
# 6/6 - 0s - loss: 0.0042 - val_loss: 0.0025 - 99ms/epoch - 17ms/step
# Epoch 44/50
# 6/6 - 0s - loss: 0.0041 - val_loss: 0.0025 - 125ms/epoch - 21ms/step
# Epoch 45/50
# 6/6 - 0s - loss: 0.0041 - val_loss: 0.0025 - 127ms/epoch - 21ms/step
# Epoch 46/50
# 6/6 - 0s - loss: 0.0041 - val_loss: 0.0025 - 133ms/epoch - 22ms/step
# Epoch 47/50
# 6/6 - 0s - loss: 0.0041 - val_loss: 0.0025 - 130ms/epoch - 22ms/step
# Epoch 48/50
# 6/6 - 0s - loss: 0.0040 - val_loss: 0.0025 - 117ms/epoch - 20ms/step
# Epoch 49/50
# 6/6 - 0s - loss: 0.0040 - val_loss: 0.0024 - 118ms/epoch - 20ms/step
# Epoch 50/50
# 6/6 - 0s - loss: 0.0040 - val_loss: 0.0024 - 115ms/epoch - 19ms/step

# %%
# Plot the loss curves
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='validation')
pyplot.legend()
pyplot.show()

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_4 (GRU)                 (None, 3, 128)            53376
#
#  gru_5 (GRU)                 (None, 64)                37248
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 92,737
# Trainable params: 92,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save('GRU_30to3.h5')

# %%
yhat = model.predict(X_test, verbose=0)

# %%
rmse = sqrt(mean_squared_error(y_test, yhat))
print(rmse)
# Out:
# 0.049316254213270024

# %%
# %% --------------------------------------- Plot the result  -----------------------------------------------------------------
## TRAIN DATA
def plot_traindataset_result(X_train, y_train):
    train_yhat = model.predict(X_train, verbose=0)

    y_scaler = load(open('y_scaler.pkl', 'rb'))
    train_predict_index = np.load("index_train.npy", allow_pickle=True)

    rescaled_real_y = y_scaler.inverse_transform(y_train)
    rescaled_predicted_y = y_scaler.inverse_transform(train_yhat)

    predict_result = pd.DataFrame()
    for i in range(rescaled_predicted_y.shape[0]):
        y_predict = pd.DataFrame(rescaled_predicted_y[i], columns=["predicted_price"],
                                 index=train_predict_index[i:i + output_dim])
        predict_result = pd.concat([predict_result, y_predict], axis=1, sort=False)

    real_price = pd.DataFrame()
    for i in range(rescaled_real_y.shape[0]):
        y_train = pd.DataFrame(rescaled_real_y[i], columns=["real_price"],
                               index=train_predict_index[i:i + output_dim])
        real_price = pd.concat([real_price, y_train], axis=1, sort=False)

    predict_result['predicted_mean'] = predict_result.mean(axis=1)
    real_price['real_mean'] = real_price.mean(axis=1)

    # Plot the predicted result
    plt.figure(figsize=(16, 8))
    plt.plot(real_price["real_mean"])
    plt.plot(predict_result["predicted_mean"], color='r')
    plt.xlabel("Date")
    plt.ylabel("Stock price")
    plt.legend(("Real price", "Predicted price"), loc="upper left", fontsize=16)
    plt.title("The result of Train", fontsize=20)
    plt.show()

    # Calculate RMSE
    predicted = predict_result["predicted_mean"]
    real = real_price["real_mean"]
    For_MSE = pd.concat([predicted, real], axis=1)
    RMSE = np.sqrt(mean_squared_error(predicted, real))
    #print('-- Train RMSE -- ', RMSE)

    return RMSE

# %%
train_RMSE = plot_traindataset_result(X_train, y_train)
print("----- Train_RMSE_GRU -----", train_RMSE)
# Out:
# C:\Users\ASUS\anaconda3\envs\gpu_env\lib\site-packages\sklearn\base.py:348: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.2.2 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11496\776994480.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   predict_result['predicted_mean'] = predict_result.mean(axis=1)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11496\776994480.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   real_price['real_mean'] = real_price.mean(axis=1)
# ----- Train_RMSE_GRU ----- 57.20243934701333

# %%
# %% --------------------------------------- Plot the result  -----------------------------------------------------------------
def plot_testdataset_result(X_test, y_test):
    test_yhat = model.predict(X_test, verbose=0)
    y_scaler = load(open('y_scaler.pkl', 'rb'))
    test_predict_index = np.load("index_test.npy", allow_pickle=True)

    rescaled_real_y = y_scaler.inverse_transform(y_test)
    rescaled_predicted_y = y_scaler.inverse_transform(test_yhat)

    predict_result = pd.DataFrame()
    for i in range(rescaled_predicted_y.shape[0]):
        y_predict = pd.DataFrame(rescaled_predicted_y[i], columns=["predicted_price"],
                                 index=test_predict_index[i:i + output_dim])
        predict_result = pd.concat([predict_result, y_predict], axis=1, sort=False)

    real_price = pd.DataFrame()
    for i in range(rescaled_real_y.shape[0]):
        y_train = pd.DataFrame(rescaled_real_y[i], columns=["real_price"],
                               index=test_predict_index[i:i + output_dim])
        real_price = pd.concat([real_price, y_train], axis=1, sort=False)

    predict_result['predicted_mean'] = predict_result.mean(axis=1)
    real_price['real_mean'] = real_price.mean(axis=1)

    # Plot the predicted result
    plt.figure(figsize=(16, 8))
    plt.plot(real_price["real_mean"])
    plt.plot(predict_result["predicted_mean"], color='r')
    plt.xlabel("Date")
    plt.ylabel("Stock price")
    plt.legend(("Real price", "Predicted price"), loc="upper left", fontsize=16)
    plt.title("The result of Testing", fontsize=20)
    plt.show()

    # Calculate RMSE
    predicted = predict_result["predicted_mean"]
    real = real_price["real_mean"]
    RMSE = np.sqrt(mean_squared_error(predicted, real))

    return RMSE

# %%
test_RMSE = plot_testdataset_result(X_test, y_test)
print("----- Test_RMSE_GRU -----", test_RMSE)
# Out:
# C:\Users\ASUS\anaconda3\envs\gpu_env\lib\site-packages\sklearn\base.py:348: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.2.2 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11496\2356792897.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   predict_result['predicted_mean'] = predict_result.mean(axis=1)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11496\2356792897.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   real_price['real_mean'] = real_price.mean(axis=1)
# ----- Test_RMSE_GRU ----- 44.73145068090449
